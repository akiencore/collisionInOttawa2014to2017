# %% [raw]
# <style>
# input[type = text] {
#     padding: 3px 2px;
#     text-align: right;
# }
# table, td {
#     border: 2px solid black;
#     padding: 3px 2px;
# }
# </style>
#
# <form>
#     <table>
#         <tr>
#             <td align="left">Date to predict: </td>
#             <td align="left">
#                 <input name="dateToPredict" id="dateToPredict" type="Date" min="2018-08-31" max="2021-12-31">
#             </td>
#         </tr>
#
#         <tr>
#             <td>The duration as the 'previous' date: </td>
#             <td colspan="1">
#                   <input type = "radio"
# 		                 name = "prev_days"
# 		                 id = "prev_oneDay"
# 		                 value = "0"
#                          checked = "checked" />
# 		          <label for = "prev_1days"> 1 day before the predicted date </label>
#                   <br/>
#                   <input type = "radio"
# 		                 name = "prev_days"
# 		                 id = "prev_twoDays"
# 		                 value = "1" />
# 		          <label for = "prev_2days"> 2 days before the predicted date </label>
#             </td>
#         </tr>
#
#         <tr>
#             <td>Snow level according to the weather forecast: </td>
#             <td colspan="1">
#                   <p>
# 		          <input type = "radio"
# 		                 name = "snowLevel"
# 		                 id = "snowlevel0"
# 		                 value = "0"
# 		                 checked = "checked" />
# 		          <label for = "snowlevel0"> less than 2 inches (5.08 cms)</label>
#                   <br/>
# 		          <input type = "radio"
# 		                 name = "snowLevel"
# 		                 id = "snowlevel1"
# 		                 value = "1"/>
# 		          <label for = "snowlevel1">  2-4 inches (5.08 cms-10.16 cms)</label>
# 		          <br/>
# 		          <input type = "radio"
# 		                 name = "snowLevel"
# 		                 id = "snowlevel2"
# 		                 value = "2"/>
# 		          <label for = "snowlevel2">  4-8 inches (10.16 cms-20.32cms)</label>
#                   <br/>
# 		          <input type = "radio"
# 		                 name = "snowLevel"
# 		                 id = "snowlevel3"
# 		                 value = "3" />
# 		          <label for = "snowlevel3"> over 8 inches (20.32cms)</label>
#                   </p>
#             </td>
#         </tr>
#
#         <tr>
#             <td>Maximum Temp on the 'previous' date: </td>
#             <td><input id="maxTemp" type="text" onkeypress="return isFloat(event)"> °C</td>
#         </tr>
#
#         <tr>
#             <td>Minimum Temp on the 'previous' date: </td>
#             <td><input id="minTemp" type="text" onkeypress="return isFloat(event)"> °C</td>
#         </tr>
#
#         <tr>
#             <td>Number of collisions on the 'previous' date: </td>
#             <td><input id="numCollisions" type="text" value="0" onkeypress="return isPosInt(event)"> cases</td>
#         </tr>
#
#
#         <tr>
#             <td>Total Rain on 'previous' date: </td>
#             <td><input id="totalRain" type="text" value="0.0" onkeypress="return isFloat(event)"> mm</td>
#         </tr>
#
#         <tr>
#             <td>Total Snow on 'previous' date: </td>
#             <td><input id="totalSnow" type="text" value="0.0" onkeypress="return isFloat(event)"> cm</td>
#         </tr>
#     </table>
#
#     <input type="button" value="Get the predict number of collisions" id="predictButton" onClick="getPredict()"></input>
#     <p> <label id="outputStr"></label> </p>
#     <p> <label id="outputStr2"></label> </p>
#
# </form>
#
# <script>
#     <!-- To insert a date today -->
#     var d = new Date()
#     var dmonth = d.getMonth()+1
#     var ddate = d.getDate()
#     if(dmonth<10){
#         dmonth = '0'+dmonth
#     }
#     if(ddate<10){
#         ddate = '0'+ddate
#     }
#
#     document.getElementById("dateToPredict").value = d.getFullYear() + '-' + dmonth + '-' + ddate
#
#     function isPosInt(evt){
#         <!-- The property of event.which: https://stackoverflow.com/questions/3050984/javascript-event-e-which -->
#         var charCode = (evt.which) ? evt.which : evt.keyCode
#         if (charCode < 48 || charCode > 57) {
#             alert('Please enter only positive integer value');
#             return false;
#         }
#         return true;
#     }
#
#
#     <!-- https://stackoverflow.com/questions/9326653/javascript-for-float-and-integer-number-validation -->
#     function isFloat(evt){
#         var charCode = (evt.which) ? evt.which : evt.keyCode
#         if ((charCode != 45) && (charCode != 46) && (charCode < 48 || charCode > 57)) {
#             alert('Please enter only float value');
#             return false;
#         }
#         else {
#             var parts = evt.srcElement.value.split('.');
#
#             if ((evt.srcElement.value[0]=="-"|| (evt.srcElement.value[0]>=0 && evt.srcElement.value[0]<=9)) && charCode == 45){
#                 return false;
#             }
#
#             if (parts.length >=2 && charCode == 46){
#                 return false;
#             }
#
#             if (evt.srcElement.value[0]=="." && charCode == 46){
#                 return false;
#             }
#         }
#         return true;
#     }
#
# </script>
#
# <script>
#     function getPredict(){
#         var dateToPredict = document.getElementById("dateToPredict").value
#         var prev_days = parseInt(document.querySelector('input[name="prev_days"]:checked').value)
#         var snow_level = parseInt(document.querySelector('input[name="snowLevel"]:checked').value)
#         var max_temp = parseFloat(document.getElementById("maxTemp").value)
#         var min_temp = parseFloat(document.getElementById("minTemp").value)
#         var numCol = parseInt(document.getElementById("numCollisions").value)
#         var rain_total = parseFloat(document.getElementById("totalRain").value)
#         var snow_total = parseFloat(document.getElementById("totalSnow").value)
#
#         var dt = new Date();
#         var tz = dt.toString().split("GMT")[1].slice(0,5)
#
#         var day_of_week = new Date(dateToPredict + " GMT" + tz).getDay()
#
#         var on_Mon = 0, on_Tue = 0, on_Wed = 0, on_Thu = 0, on_Fri = 0, on_Sat = 0, on_Sun = 0
#         var on_Holiday = 0, post_Holiday = 0
#
#         switch (day_of_week) {
#             case 0:
#                 on_Sun = 1;
#                 break;
#             case 1:
#                 on_Mon = 1;
#                 break;
#             case 2:
#                 on_Tue = 1;
#                 break;
#             case 3:
#                 on_Wed = 1;
#                 break;
#             case 4:
#                 on_Thu = 1;
#                 break;
#             case 5:
#                 on_Fri = 1;
#                 break;
#             case 6:
#                 on_Sat = 1;
#         }
#
#
#         typeOfHoliday = holidaysDict[dateToPredict]
#
#
#         if(typeOfHoliday == "onHoliday") {
#             on_Holiday = 1;
#         } else if(typeOfHoliday == "postHoliday"){
#             post_Holiday = 1;
#         }
#
#         getNumCollisions(prev_days, snow_level, max_temp, min_temp, numCol, rain_total, snow_total, on_Mon, on_Tue, on_Wed, on_Thu, on_Fri, on_Sat, on_Sun, on_Holiday, post_Holiday);
#     }
#
# function getNumCollisions(prev_days=0, snow_level=0, max_temp=0, min_temp=0, numCol=0, rain_total, snow_total, on_Mon = 0, on_Tue = 0, on_Wed = 0, on_Thu = 0, on_Fri = 0, on_Sat = 0, on_Sun = 0, on_Holiday = 0, post_Holiday = 0){
#     var output, exponent, thirdQuartile = 47;
#     if(prev_days==0){
#         output =  parameterForOneDay["b0"]
#                 + parameterForOneDay["b1"]*min_temp
#                 + parameterForOneDay["b2"]*rain_total
#                 + parameterForOneDay["b3"]*snow_total
#                 + parameterForOneDay["b4"]*on_Mon
#                 + parameterForOneDay["b5"]*on_Tue
#                 + parameterForOneDay["b6"]*on_Wed
#                 + parameterForOneDay["b7"]*on_Thu
#                 + parameterForOneDay["b8"]*on_Fri
#                 + parameterForOneDay["b9"]*on_Holiday
#                 + parameterForOneDay["b10"]*post_Holiday
#                 + parameterForOneDay["b11"]*numCol
#                 + parameterForOneDay["b12"]*snow_level;
#
#         exponent = logForOneDay["b0"]
#                 + logForOneDay["b1"]*min_temp
#                 + logForOneDay["b2"]*rain_total
#                 + logForOneDay["b3"]*snow_total
#                 + logForOneDay["b4"]*on_Mon
#                 + logForOneDay["b5"]*on_Tue
#                 + logForOneDay["b6"]*on_Wed
#                 + logForOneDay["b7"]*on_Thu
#                 + logForOneDay["b8"]*on_Fri
#                 + logForOneDay["b9"]*on_Holiday
#                 + logForOneDay["b10"]*post_Holiday
#                 + logForOneDay["b11"]*numCol
#                 + logForOneDay["b12"]*snow_level;
#
#     } else if(prev_days==1){
#         output =  parameterForTwoDays["b0"]
#                 + parameterForTwoDays["b1"]*max_temp
#                 + parameterForTwoDays["b2"]*min_temp
#                 + parameterForTwoDays["b3"]*rain_total
#                 + parameterForTwoDays["b4"]*snow_total
#                 + parameterForTwoDays["b5"]*on_Mon
#                 + parameterForTwoDays["b6"]*on_Tue
#                 + parameterForTwoDays["b7"]*on_Wed
#                 + parameterForTwoDays["b8"]*on_Thu
#                 + parameterForTwoDays["b9"]*on_Fri
#                 + parameterForTwoDays["b10"]*on_Sat
#                 + parameterForTwoDays["b11"]*on_Sun
#                 + parameterForTwoDays["b12"]*on_Holiday
#                 + parameterForTwoDays["b13"]*post_Holiday
#                 + parameterForTwoDays["b14"]*numCol
#                 + parameterForTwoDays["b15"]*snow_level;
#
#         exponent =  logForTwoDays["b0"]
#                 + logForTwoDays["b1"]*max_temp
#                 + logForTwoDays["b2"]*min_temp
#                 + logForTwoDays["b3"]*rain_total
#                 + logForTwoDays["b4"]*snow_total
#                 + logForTwoDays["b5"]*on_Mon
#                 + logForTwoDays["b6"]*on_Tue
#                 + logForTwoDays["b7"]*on_Wed
#                 + logForTwoDays["b8"]*on_Thu
#                 + logForTwoDays["b9"]*on_Fri
#                 + logForTwoDays["b10"]*on_Sat
#                 + logForTwoDays["b11"]*on_Sun
#                 + logForTwoDays["b12"]*on_Holiday
#                 + logForTwoDays["b13"]*post_Holiday
#                 + logForTwoDays["b14"]*numCol
#                 + logForTwoDays["b15"]*snow_level;
#
#
#     }
#     document.getElementById("outputStr").innerHTML = "The expected number of collisions on " + document.getElementById("dateToPredict").value + " would be around " + output + " cases.";
#     document.getElementById("outputStr2").innerHTML = "The number of collisions on " + document.getElementById("dateToPredict").value + " has the probability of " + 1/(1+Math.exp(-exponent)) + " to be more than " + thirdQuartile +" cases.";
# }
#
# </script>
#
# <script>
#     var parameterForOneDay = {
#         "b0" : 17.05623348065217,
#         "b1" : -0.268894,
#         "b2" : 0.039289,
#         "b3" : 1.131121,
#         "b4" : 15.499759,
#         "b5" : 14.373184,
#         "b6" : 14.527986,
#         "b7" : 17.622600,
#         "b8" : 18.878457,
#         "b9" : -18.203469,
#         "b10" : 10.680958,
#         "b11" : 0.276622,
#         "b12" : 12.924866
#     }
#
#     var logForOneDay = {
#         "b0" : -3.5612317813495302,
#         "b1" : -0.046209,
#         "b2" : 0.010778,
#         "b3" : 0.042258,
#         "b4" : 1.394866,
#         "b5" : 1.367854,
#         "b6" : 1.287484,
#         "b7" : 1.835366,
#         "b8" : 2.074457,
#         "b9" : -1.406767,
#         "b10" : 0.893741,
#         "b11" : 0.027206,
#         "b12" : 1.032811
#     }
#
#     /* Where:
#        y = the number of collisions
#        x1 = minimum temperature of the previous date (in °C)
#        x2 = rain amount of the previous date (in mm)
#        x3 = snow amount of the previous date (in cm)
#        x4 = it is on Monday (0 or 1)
#        x5 = it is on Tuesday (0 or 1)
#        x6 = it is on Wednesday (0 or 1)
#        x7 = it is on Thursday (0 or 1)
#        x8 = it is on Friday (0 or 1)
#        x9 = it is on a holiday (0 or 1)
#        x10= it is the workday after holiday (0 or 1)
#        x11= the number of collisions on yesterday
#        x12= snow level (a whole number from 0 to 3 depend on snow emergency level) */
#
#
#     var parameterForTwoDays = {
#         "b0" : 33.23958358459631,
#         "b1" : -0.134663,
#         "b2" : -0.186101,
#         "b3" : -0.093392,
#         "b4" : 0.289532,
#         "b5" : 1.787691,
#         "b6" : 5.707546,
#         "b7" : 4.960383,
#         "b8" : 6.007504,
#         "b9" : 8.115494,
#         "b10" : -9.925716,
#         "b11" : -16.652902,
#         "b12" : -20.583982,
#         "b13" : 6.853835,
#         "b14" : 0.218333,
#         "b15" : 12.102903
#     }
#
#     var logForTwoDays = {
#         "b0" : -1.863035745717911,
#         "b1" : -0.049913,
#         "b2" : 0.000285,
#         "b3" : -0.014031,
#         "b4" : 0.002562,
#         "b5" : -0.040684,
#         "b6" : 0.574795,
#         "b7" : 0.269143,
#         "b8" : 0.622278,
#         "b9" : 0.884171,
#         "b10" : -1.603912,
#         "b11" : -2.568828,
#         "b12" : -2.030745,
#         "b13" : 0.463170,
#         "b14" : 0.030241,
#         "b15" : 1.146361
#     }
#
#     /* Where:
#        y = the number of collisions
#        x1 = maximum temperature of 2 days ago (in °C)
#        x2 = minimum temperature of 2 days ago (in °C)
#        x3 = rain amount of 2 days ago (in mm)
#        x4 = snow amount of 2 days ago (in cm)
#        x5 = it is on Monday (0 or 1)
#        x6 = it is on Tuesday (0 or 1)
#        x7 = it is on Wednesday (0 or 1)
#        x8 = it is on Thursday (0 or 1)
#        x9 = it is on Friday (0 or 1)
#        x10= it is on Saturday (0 or 1)
#        x11= it is on Sunday (0 or 1)
#        x12= it is on a holiday (0 or 1)
#        x13= it is the workday after holiday (0 or 1)
#        x14= the number of collisions on yesterday
#        x15= snow level (a whole number from 0 to 3 depend on snow emergency level) */
#
#     var holidaysDict = {
#         "2018-01-01" : "onHoliday",
#         "2018-01-02" : "onHoliday",
#         "2018-01-03" : "postHoliday",
#         "2018-07-01" : "onHoliday",
#         "2019-12-25" : "onHoliday"
# }
#
# </script>
